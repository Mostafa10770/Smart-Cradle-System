# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# Load the sensor data from the Excel file
sensor_data = pd.read_excel('sensor_data_updated.xlsx')

# %%
# Data Cleaning
# Example: Handling missing values (if any)
sensor_data.dropna(inplace=True)

# %%
# Adjust data types convert from cateogrical to numerical
sensor_data['Timestamp'] = pd.to_datetime(sensor_data['Timestamp'])  # Convert Timestamp to datetime type
sensor_data['Stepper Position'] = sensor_data['Stepper Position'].astype('category')  # Convert Stepper Position to categorical type

# %%
# Convert 'Rain Sensor' and 'Camera Streaming' columns to categorical
sensor_data['Rain Sensor'] = sensor_data['Rain Sensor'].astype('category')
sensor_data['Camera Streaming'] = sensor_data['Camera Streaming'].astype('category')

# %%
# Perform data visualization
sns.histplot(data=sensor_data, x='Microphone', bins=10)
plt.title('Microphone Reading Distribution')
plt.xlabel('Microphone Value')
plt.ylabel('Count')
plt.show()

# %%
# Perform data analysis and visualization
# Example: Plotting the distribution of the microphone readings
sns.histplot(data=sensor_data, x='Microphone', bins=10)
plt.title('Microphone Reading Distribution')
plt.xlabel('Microphone Value')
plt.ylabel('Count')
plt.show()

# %%
# Example: Bar plot of Cradle Movement counts
sns.countplot(data=sensor_data, x='Cradle Movement')
plt.title('Cradle Movement Counts')
plt.xlabel('Cradle Movement')
plt.ylabel('Count')
plt.show()

# %%
# Perform additional data visualizations
# Example: Box plot of Microphone readings by Cradle Movement
plt.figure(figsize=(8, 6))
sns.boxplot(data=sensor_data, x='Cradle Movement', y='Microphone')
plt.title('Microphone Readings by Cradle Movement')
plt.xlabel('Cradle Movement')
plt.ylabel('Microphone Value')
plt.show()

# %%
# Example: Count plot of Rain Sensor
plt.figure(figsize=(6, 4))
sns.countplot(data=sensor_data, x='Rain Sensor')
plt.title('Rain Sensor Counts')
plt.xlabel('Rain Sensor')
plt.ylabel('Count')
plt.show()

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt

# Load the sensor data from the Excel file
sensor_data = pd.read_excel('sensor_data_updated.xlsx')

# Data Cleaning
# Example: Handling missing values (if any)
sensor_data.dropna(inplace=True)
# Adjust data types convert from categorical to numerical
sensor_data['Timestamp'] = pd.to_datetime(sensor_data['Timestamp'])  # Convert Timestamp to datetime type
sensor_data['Stepper Position'] = sensor_data['Stepper Position'].astype('category')  # Convert Stepper Position to categorical type
# Convert 'Rain Sensor' and 'Camera Streaming' columns to categorical
sensor_data['Rain Sensor'] = sensor_data['Rain Sensor'].astype('category')
sensor_data['Camera Streaming'] = sensor_data['Camera Streaming'].astype('category')

# Split the data into features (X) and target variable (y)
X = sensor_data.drop(['Cradle Movement', 'Timestamp'], axis=1)
y = sensor_data['Cradle Movement']

# Perform one-hot encoding on the categorical features
X_encoded = pd.get_dummies(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Create and train the Random Forest Classifier
model1 = RandomForestClassifier(n_estimators=100, random_state=42)
model1.fit(X_train, y_train)

# Make predictions on the test set
y_pred_model1 = model1.predict(X_test)

# Evaluate the model
accuracy_model1 = accuracy_score(y_test, y_pred_model1)
confusion_mat_model1 = confusion_matrix(y_test, y_pred_model1)

# Create and train the SVM classifier
model2 = SVC(kernel='linear', random_state=42)
model2.fit(X_train, y_train)

# Make predictions on the test set
y_pred_model2 = model2.predict(X_test)

# Evaluate the model
accuracy_model2 = accuracy_score(y_test, y_pred_model2)
confusion_mat_model2 = confusion_matrix(y_test, y_pred_model2)

# Create a bar graph to compare the accuracies of the two models
models = ['Model 1', 'Model 2']
accuracies = [accuracy_model1, accuracy_model2]

plt.bar(models, accuracies)
plt.title('Accuracy Comparison')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.ylim(0, 1)  # Set the y-axis limits
plt.show()

# %%
# Load the sensor data from the Excel file
sensor_data = pd.read_excel('sensor_data_updated.xlsx')

# Data Cleaning
# Example: Handling missing values (if any)
sensor_data.dropna(inplace=True)
# Adjust data types convert from categorical to numerical
sensor_data['Timestamp'] = pd.to_datetime(sensor_data['Timestamp'])  # Convert Timestamp to datetime type
sensor_data['Stepper Position'] = sensor_data['Stepper Position'].astype('category')  # Convert Stepper Position to categorical type
# Convert 'Rain Sensor' and 'Camera Streaming' columns to categorical
sensor_data['Rain Sensor'] = sensor_data['Rain Sensor'].astype('category')
sensor_data['Camera Streaming'] = sensor_data['Camera Streaming'].astype('category')

# Split the data into features (X) and target variable (y)
X = sensor_data.drop(['Cradle Movement', 'Timestamp'], axis=1)
y = sensor_data['Cradle Movement']

# Perform one-hot encoding on the categorical features
X_encoded = pd.get_dummies(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Create and train the Random Forest Classifier
model1 = RandomForestClassifier(n_estimators=100, random_state=42)
model1.fit(X_train, y_train)

# Create and train the SVM classifier
model2 = SVC(kernel='linear', random_state=42)
model2.fit(X_train, y_train)

# Test the data using Model 1
y_pred_model1 = model1.predict(X_test)

# Test the data using Model 2
y_pred_model2 = model2.predict(X_test)

# Print the predictions
print("Model 1 Predictions:", y_pred_model1)
print("Model 2 Predictions:", y_pred_model2)
# Out:
# Model 1 Predictions: ['Moving' 'Stationary' 'Stationary' ... 'Moving' 'Stationary' 'Moving']
# Model 2 Predictions: ['Moving' 'Stationary' 'Stationary' ... 'Moving' 'Stationary' 'Moving']
